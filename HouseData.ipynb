# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

# %%
df=pd.read_excel("Nashville Housing Data for Data Cleaning.xlsx", parse_dates=['SaleDate'])

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.dtypes
# Out:
# UniqueID                    int64
# ParcelID                   object
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# LegalReference             object
# SoldAsVacant               object
# OwnerName                  object
# OwnerAddress               object
# Acreage                   float64
# TaxDistrict                object
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBath                  float64
# HalfBath                  float64
# dtype: object

# %%
df.iloc[[159,223]]
# Out:
#      UniqueID          ParcelID                  LandUse PropertyAddress  \
# 159      43076  025 07 0 031.00            SINGLE FAMILY             NaN
# 223      39432  026 01 0 069.00  VACANT RESIDENTIAL LAND             NaN
#
#       SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 159 2016-01-15     179900  20160120-0005776           No
# 223 2015-10-23     153000  20151028-0109602           No
#
#                         OwnerName                            OwnerAddress  \
# 159       COSTNER, FRED & CAROLYN    410  ROSEHILL CT, GOODLETTSVILLE, TN
# 223  SHACKLEFORD, MICHAEL C., JR.  141  TWO MILE PIKE, GOODLETTSVILLE, TN
#
#      Acreage             TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 159     0.96  CITY OF GOODLETTSVILLE    30000.0        70000.0    100000.0
# 223     0.17  CITY OF GOODLETTSVILLE    21100.0       121600.0    142700.0
#
#      YearBuilt  Bedrooms  FullBath  HalfBath
# 159     1964.0       3.0       1.0       0.0
# ...

# %%
xxx=df['PropertyAddress'].isna()
xxx
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56472    False
# 56473    False
# 56474    False
# 56475    False
# 56476    False
# Name: PropertyAddress, Length: 56477, dtype: bool

# %%
xxx.sum()
# Out:
# 29

# %%
# replace n and y by no and yes
df['SoldAsVacant'].replace({'N':'No', 'Y':'Yes'})
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 56472     No
# 56473     No
# 56474    Yes
# 56475    Yes
# 56476    Yes
# Name: SoldAsVacant, Length: 56477, dtype: object

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['UniqueID', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
df.set_index('UniqueID',inplace=True)

# %%
# remove duplicates
df.duplicated()
# Out:
# 102

# %%
xxx=df.drop_duplicates()
xxx.shape
# Out:
# (56375, 18)

# %%
xxx
# Out:
#                   ParcelID                  LandUse  \
# UniqueID
# 2045       007 00 0 125.00            SINGLE FAMILY
# 16918      007 00 0 130.00            SINGLE FAMILY
# 54582      007 00 0 138.00            SINGLE FAMILY
# 43070      007 00 0 143.00            SINGLE FAMILY
# 22714      007 00 0 149.00            SINGLE FAMILY
# ...                    ...                      ...
# 30469     188 10 0A 101.00            SINGLE FAMILY
# 27707     188 10 0A 107.00            SINGLE FAMILY
# 52709     188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 54042     188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 54043     188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                               PropertyAddress   SaleDate  SalePrice  \
# UniqueID
# 2045       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 16918      1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 54582      1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# ...

# %%
#  chop address to multiple columns
yyy=xxx['OwnerAddress'].str.split(pat=',', expand=True)
yyy.columns=['address','city','state']
#xxx.loc[:,'Split_Address']=yyy['address']
xxx.insert(3,"Split_Address",yyy['address'])
xxx
# Out:
#                   ParcelID                  LandUse  \
# UniqueID
# 2045       007 00 0 125.00            SINGLE FAMILY
# 16918      007 00 0 130.00            SINGLE FAMILY
# 54582      007 00 0 138.00            SINGLE FAMILY
# 43070      007 00 0 143.00            SINGLE FAMILY
# 22714      007 00 0 149.00            SINGLE FAMILY
# ...                    ...                      ...
# 30469     188 10 0A 101.00            SINGLE FAMILY
# 27707     188 10 0A 107.00            SINGLE FAMILY
# 52709     188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 54042     188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 54043     188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                               PropertyAddress       Split_Address   SaleDate  \
# UniqueID
# 2045       1808  FOX CHASE DR, GOODLETTSVILLE  1808  FOX CHASE DR 2013-04-09
# 16918      1832  FOX CHASE DR, GOODLETTSVILLE  1832  FOX CHASE DR 2014-06-10
# 54582      1864 FOX CHASE  DR, GOODLETTSVILLE  1864  FOX CHASE DR 2016-09-26
# ...

# %%
xxx.drop(columns=['Split_Address'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-d822f6dd5656> in <module>
# ----> 1 xxx.drop(columns=['Split_Address'], inplace=True)
#       2 xxx
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
xxx
# Out:
#                   ParcelID                  LandUse  \
# UniqueID
# 2045       007 00 0 125.00            SINGLE FAMILY
# 16918      007 00 0 130.00            SINGLE FAMILY
# 54582      007 00 0 138.00            SINGLE FAMILY
# 43070      007 00 0 143.00            SINGLE FAMILY
# 22714      007 00 0 149.00            SINGLE FAMILY
# ...                    ...                      ...
# 30469     188 10 0A 101.00            SINGLE FAMILY
# 27707     188 10 0A 107.00            SINGLE FAMILY
# 52709     188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 54042     188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 54043     188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                               PropertyAddress   SaleDate  SalePrice  \
# UniqueID
# 2045       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 16918      1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 54582      1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# ...

# %%
xxx.insert(3,'Split_Address',yyy['address'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-5f709719e0f5> in <module>
# ----> 1 xxx.insert(3,'Split_Address',yyy['address'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3574         self._ensure_valid_index(value)
#    3575         value = self._sanitize_column(column, value, broadcast=False)
# -> 3576         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3577
#    3578     def assign(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# ...

# %%
xxx
# Out:
#                   ParcelID                  LandUse  \
# UniqueID
# 2045       007 00 0 125.00            SINGLE FAMILY
# 16918      007 00 0 130.00            SINGLE FAMILY
# 54582      007 00 0 138.00            SINGLE FAMILY
# 43070      007 00 0 143.00            SINGLE FAMILY
# 22714      007 00 0 149.00            SINGLE FAMILY
# ...                    ...                      ...
# 30469     188 10 0A 101.00            SINGLE FAMILY
# 27707     188 10 0A 107.00            SINGLE FAMILY
# 52709     188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 54042     188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 54043     188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                               PropertyAddress       Split_Address   SaleDate  \
# UniqueID
# 2045       1808  FOX CHASE DR, GOODLETTSVILLE  1808  FOX CHASE DR 2013-04-09
# 16918      1832  FOX CHASE DR, GOODLETTSVILLE  1832  FOX CHASE DR 2014-06-10
# 54582      1864 FOX CHASE  DR, GOODLETTSVILLE  1864  FOX CHASE DR 2016-09-26
# ...

# %%
df.loc[df['PropertyAddress'].isna()]
# Out:
#        UniqueID           ParcelID                  LandUse PropertyAddress  \
# 159        43076   025 07 0 031.00            SINGLE FAMILY             NaN
# 223        39432   026 01 0 069.00  VACANT RESIDENTIAL LAND             NaN
# 246        45290   026 05 0 017.00            SINGLE FAMILY             NaN
# 305        53147  026 06 0A 038.00        RESIDENTIAL CONDO             NaN
# 531        43080   033 06 0 041.00            SINGLE FAMILY             NaN
# 533        45295  033 06 0A 002.00            SINGLE FAMILY             NaN
# 665        48731   033 15 0 123.00            SINGLE FAMILY             NaN
# 858        36531   034 03 0 059.00            SINGLE FAMILY             NaN
# 1043       46919  034 07 0B 015.00  VACANT RESIDENTIAL LAND             NaN
# 1176       44264  034 16 0A 004.00  VACANT RESIDENTIAL LAND             NaN
# 1262       45298  041 03 0A 100.00            SINGLE FAMILY             NaN
# ...

# %%
df.shape
# Out:
# (56477, 18)

# %%
df.columns=df.columns.str.strip()  #Remove leading and trailing characters. If None then whitespaces are removed
df.columns
# Out:
# Index(['UniqueID', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
conn=create_engine('mysql+pymysql://root:yxdj87212241@localhost/house_proj')
df.to_sql('house_data', conn, index=False, if_exists='replace')
